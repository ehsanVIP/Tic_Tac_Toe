# %%
def checkInput(r, c, rowA, rowB, rowC):
    if (r > 2 or c > 2 ) :
        return False
    if r == 0:
        if (rowA[c] != "." ):
            return False
        else: return True
    if r == 1:
        if (rowB[c] != "." ):
            return False
        else: return True
    if r == 2:
        if (rowC[c] != "." ):
            return False
        
        else: return True
    else: 
        return True

# %%
def checkTerminateState(turn_x, rowA, rowB, rowC):
    if (rowA[0] == rowA[1]) and (rowA[0] == rowA[2]) and (rowA[2] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowA[2] ,"is Winner !")
        return True
    if (rowB[0] == rowB[1]) and (rowB[0] == rowB[2]) and (rowB[2] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowB[2] ,"is Winner !")
        return True
    if (rowC[0] == rowC[1]) and (rowC[0] == rowC[2]) and (rowC[2] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowC[2] ,"is Winner !")
        return True
    if (rowA[0] == rowB[0]) and (rowB[0] == rowC[0]) and (rowC[0] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowC[0] ,"is Winner !")
        return True
    if (rowA[1] == rowB[1]) and (rowB[1] == rowC[1]) and (rowC[1] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowC[1] ,"is Winner !")
        return True
    if (rowA[2] == rowB[2]) and (rowB[2] == rowC[2]) and (rowC[2] != ".") :
        printer(rowA,rowB,rowC)
        print("\n", rowC[2] ,"is Winner !")
        return True
    if (rowA[0] == rowB[1]) and (rowB[1] == rowC[2]) and (rowC[2] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowC[2] ,"is Winner !")
        return True
    if (rowA[2] == rowB[1]) and (rowB[1] == rowC[0]) and (rowC[0] != ".") :
        printer(rowA,rowB,rowC)
        print("\n",rowC[0] ,"is Winner !")
        return True
    if ("." not in rowA) and ("." not in rowB) and ("." not in rowC):
        printer(rowA,rowB,rowC)
        print("\n",'Draw')
        return True

# %%
def printer(rowA,rowB,rowC):
    print("   0     1     2")
    print("0 ", end=" ")
    for i in range(len(rowA)):
        print(rowA[i], end=" ")
        if i != (len(rowA)-1):
            print(" | ", end= " ")
    print("\n  ---------------")
    print("1 ", end=" ")
    for i in range(len(rowB)):
        print(rowB[i], end=" ")
        if i != (len(rowB)-1):
            print(" | ", end= " ")
    print("\n  ---------------")
    print("2 ", end=" ")
    for i in range(len(rowC)):
        print(rowC[i], end=" ")
        if i != (len(rowC)-1):
            print(" | ", end= " ")

# %%
rowA = [".",".","."]
rowB = [".",".","."]
rowC = [".",".","."]

printer(rowA,rowB,rowC)
turn = input("\nWho wants to Start ? X/O : ")
if turn == "X":
    turn_x = True
else : turn_x = False

while(True):

    if turn_x:
        inp = input("\nPlayer X : ")
        r = int(inp[0])
        c = int(inp[1])
        if checkInput(r, c, rowA, rowB, rowC):
            if r == 0:
                rowA[c] = 'X'
                turn_x = False
            elif r == 1:
                rowB[c] = 'X'
                turn_x = False
            elif r == 2:
                rowC[c] = 'X'
                turn_x = False
            if checkTerminateState(turn_x, rowA, rowB, rowC):
                break
        else : print('\nInput Error')
    else:   
        inp = input("\nPlayer O : ")
        r = int(inp[0])
        c = int(inp[1])
        if checkInput(r, c, rowA, rowB, rowC):
            if r == 0:
                rowA[c] = 'O'
                turn_x = True
            elif r == 1:
                rowB[c] = 'O'
                turn_x = True
            elif r == 2:
                rowC[c] = 'O'
                turn_x = True
            if checkTerminateState(turn_x,rowA, rowB, rowC):
                break
        else : print('\nInput Error')
        
    printer(rowA,rowB,rowC)
# Out:
# .  |  .  |  .
# --------------
# .  |  .  |  .
# --------------
# .  |  .  |  .
# Who wants to Start ? X/O : X
#
# Player X : 00
# X  |  .  |  .
# --------------
# .  |  .  |  .
# --------------
# .  |  .  |  .
# Player O : 01
# X  |  O  |  .
# --------------
# .  |  .  |  .
# --------------
# .  |  .  |  .
# Player X : 12
# X  |  O  |  .
# --------------
# .  |  .  |  X
# --------------
# .  |  .  |  .
# Player O : 11
# X  |  O  |  .
# --------------
# .  |  O  |  X
# --------------
# .  |  .  |  .
# Player X : 22
# X  |  O  |  .
# --------------
# .  |  O  |  X
# --------------
# .  |  .  |  X
# Player O : 21
# X  |  O  |  .
# --------------
# .  |  O  |  X
# --------------
# .  |  O  |  X
#  O is Winner !

# %% [markdown]
# Just Check for Printing :

# %%
rowA = [".",".","."]
rowB = [".",".","."]
rowC = [".",".","."]
printer(rowA,rowB,rowC)

# %% [markdown]
# should work with ssh
